# %%
import os
import json
from gensim.utils import simple_preprocess
from gensim.models.phrases import Phrases, Phraser
from gensim import corpora
from gensim.similarities import Similarity


path = r"G:\work\aiddata_tuff\data\Pakistan-2019-json\Pakistan"

files = os.listdir(path)
documents=[]
file_names=[]

for file in files:
    f = open(path+"\\"+file)
    data = json.load(f)
    title = data['title']
    snippet = data['snippet']
    body = data['body']
    this_text = title + " " + snippet + body
    documents.append(this_text)
    file_names.append(file)

# %%
#Convert documents to collection of words
texts = [[text for text in simple_preprocess(doc, deacc=True)] for doc in documents]

#Build a bigram model to capture every pair of words in the texts
bigram = Phrases(texts, min_count=1)
bigram_phraser = Phraser(bigram)

texts_bigrams = [[text for text in bigram_phraser[ simple_preprocess(doc, deacc=True)]] for doc in documents]

dictionary = corpora.Dictionary(texts_bigrams)

#Create corpus
corpus = [dictionary.doc2bow(docString) for docString in texts_bigrams]

#Build similarity index
index = Similarity(corpus=corpus, num_features=len(dictionary), output_prefix='on_disk_output')

# %%
#Parse similarities from index
doc_id = 0
similar_docs = {}
for similarities in index:
    similar_docs[doc_id] = list(enumerate(similarities))
    doc_id += 1

# %%
#adjust this threshold to finetune the results
sim_threshold=0.95

for doc_id, sim_doc_tuples in similar_docs.items():
    print("-------------------------------------") 
    print("Analyzing doc #", doc_id) 
    print("Filename", file_names[doc_id]) 
    this_sim_docs = [] 
    for sim_doc_tuple in sim_doc_tuples: 
        sim_doc_id = sim_doc_tuple[0] 
        sim_score = sim_doc_tuple[1] 
        if sim_score >= sim_threshold and doc_id != sim_doc_id: 
            this_sim_docs.append(file_names[sim_doc_id]) 
    print("\nSimiliar Docs:", this_sim_docs) 
    print("-------------------------------------\n")
# Out:
# -------------------------------------
# Analyzing doc # 0
# Filename pakis-1-text813733.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 1
# Filename pakis-10-text2908317.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2
# Filename pakis-100-text3397292.json
#
# Similiar Docs: ['pakis-977-text3635658.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 3
# Filename pakis-1000-text1901643.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 4
# Filename pakis-1001-text1544554.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 5
# Filename pakis-1002-text2401403.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 6
# Filename pakis-1003-text378269.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 7
# Filename pakis-1004-text969994.json
#
# Similiar Docs: ['pakis-1345-text3596455.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 8
# Filename pakis-1005-text3230912.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 9
# Filename pakis-1006-text2437507.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 10
# Filename pakis-1007-text2232840.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 11
# Filename pakis-1008-text1340979.json
#
# Similiar Docs: ['pakis-1704-text1961503.json', 'pakis-1969-text403561.json', 'pakis-29-text2100009.json', 'pakis-316-text2719832.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 12
# Filename pakis-1009-text806101.json
#
# Similiar Docs: ['pakis-539-text2204775.json', 'pakis-930-text1031288.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 13
# Filename pakis-101-text3173079.json
#
# Similiar Docs: ['pakis-1182-text1468690.json', 'pakis-1382-text1959603.json', 'pakis-453-text1632422.json', 'pakis-527-text3554240.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 14
# Filename pakis-1010-text2641392.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 15
# Filename pakis-1011-text2922622.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 16
# Filename pakis-1012-text3520460.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 17
# Filename pakis-1013-text1156662.json
#
# Similiar Docs: ['pakis-1341-text513116.json', 'pakis-162-text2167120.json', 'pakis-170-text1243811.json', 'pakis-1782-text1594911.json', 'pakis-1785-text3703265.json', 'pakis-1807-text757971.json', 'pakis-1952-text2559569.json', 'pakis-2044-text3280459.json', 'pakis-387-text1986866.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 18
# Filename pakis-1014-text3207664.json
#
# Similiar Docs: ['pakis-586-text736487.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 19
# Filename pakis-1015-text2027853.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 20
# Filename pakis-1016-text2043277.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 21
# Filename pakis-1017-text3364113.json
#
# Similiar Docs: ['pakis-1052-text2946189.json', 'pakis-1592-text10172.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 22
# Filename pakis-1018-text370108.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 23
# Filename pakis-1019-text2872834.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 24
# Filename pakis-102-text1553279.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 25
# Filename pakis-1020-text1843750.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 26
# Filename pakis-1021-text3020635.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 27
# Filename pakis-1022-text2179326.json
#
# Similiar Docs: ['pakis-873-text2038552.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 28
# Filename pakis-1023-text3738081.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 29
# Filename pakis-1024-text3384448.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 30
# Filename pakis-1025-text2735975.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 31
# Filename pakis-1026-text1467670.json
#
# Similiar Docs: ['pakis-432-text1882253.json', 'pakis-518-text624058.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 32
# Filename pakis-1027-text3373855.json
#
# Similiar Docs: ['pakis-1585-text2807331.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 33
# Filename pakis-1028-text1897912.json
#
# Similiar Docs: ['pakis-646-text1336806.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 34
# Filename pakis-1029-text941115.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 35
# Filename pakis-103-text3636505.json
#
# Similiar Docs: ['pakis-256-text2523723.json', 'pakis-464-text3265329.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 36
# Filename pakis-1030-text2951700.json
#
# Similiar Docs: ['pakis-2043-text742460.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 37
# Filename pakis-1031-text3484684.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 38
# Filename pakis-1032-text2198166.json
#
# Similiar Docs: ['pakis-2051-text294441.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 39
# Filename pakis-1033-text2233829.json
#
# Similiar Docs: ['pakis-950-text1243025.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 40
# Filename pakis-1034-text724238.json
#
# Similiar Docs: ['pakis-410-text1681144.json', 'pakis-681-text3465425.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 41
# Filename pakis-1035-text188391.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 42
# Filename pakis-1036-text979623.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 43
# Filename pakis-1037-text1024632.json
#
# Similiar Docs: ['pakis-1171-text2524891.json', 'pakis-1683-text285930.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 44
# Filename pakis-1038-text141244.json
#
# Similiar Docs: ['pakis-1818-text133345.json', 'pakis-448-text3741057.json', 'pakis-618-text319891.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 45
# Filename pakis-1039-text3700145.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 46
# Filename pakis-104-text1156502.json
#
# Similiar Docs: ['pakis-298-text1479126.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 47
# Filename pakis-1040-text3755717.json
#
# Similiar Docs: ['pakis-166-text3397840.json', 'pakis-168-text2155640.json', 'pakis-1862-text2780203.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 48
# Filename pakis-1041-text2073779.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 49
# Filename pakis-1042-text1362840.json
#
# Similiar Docs: ['pakis-1130-text2745350.json', 'pakis-1606-text2040108.json', 'pakis-1673-text2121009.json', 'pakis-1940-text475435.json', 'pakis-2031-text561532.json', 'pakis-2145-text2676717.json', 'pakis-248-text1059180.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 50
# Filename pakis-1043-text3706914.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 51
# Filename pakis-1044-text1396679.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 52
# Filename pakis-1045-text1347869.json
#
# Similiar Docs: ['pakis-1710-text3216519.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 53
# Filename pakis-1046-text1096622.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 54
# Filename pakis-1047-text3609351.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 55
# Filename pakis-1048-text1557483.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 56
# Filename pakis-1049-text2383392.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 57
# Filename pakis-105-text2151856.json
#
# Similiar Docs: ['pakis-2136-text3228577.json', 'pakis-375-text1005494.json', 'pakis-441-text2375031.json', 'pakis-599-text2405824.json', 'pakis-87-text3544709.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 58
# Filename pakis-1050-text939146.json
#
# Similiar Docs: ['pakis-996-text2659057.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 59
# Filename pakis-1051-text2036928.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 60
# Filename pakis-1052-text2946189.json
#
# Similiar Docs: ['pakis-1017-text3364113.json', 'pakis-1592-text10172.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 61
# Filename pakis-1053-text277600.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 62
# Filename pakis-1054-text1600800.json
#
# Similiar Docs: ['pakis-1747-text484599.json', 'pakis-2099-text2425204.json', 'pakis-8-text301234.json', 'pakis-955-text3579961.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 63
# Filename pakis-1055-text962069.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 64
# Filename pakis-1056-text3448376.json
#
# Similiar Docs: ['pakis-2046-text1414324.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 65
# Filename pakis-1057-text118.json
# Similiar Docs: ['pakis-1963-text1596003.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 66
# Filename pakis-1058-text2443126.json
#
# Similiar Docs: ['pakis-21-text2259552.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 67
# Filename pakis-1059-text2176935.json
#
# Similiar Docs: ['pakis-510-text1531958.json', 'pakis-998-text1298047.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 68
# Filename pakis-106-text1641167.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 69
# Filename pakis-1060-text1476480.json
#
# Similiar Docs: ['pakis-2098-text2401716.json', 'pakis-525-text1993537.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 70
# Filename pakis-1061-text1342980.json
#
# Similiar Docs: ['pakis-1887-text2530181.json', 'pakis-561-text2513624.json', 'pakis-892-text2109159.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 71
# Filename pakis-1062-text81662.json
#
# Similiar Docs: ['pakis-1260-text1879592.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 72
# Filename pakis-1063-text2724134.json
#
# Similiar Docs: ['pakis-1811-text2409407.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 73
# Filename pakis-1064-text1176322.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 74
# Filename pakis-1065-text1039361.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 75
# Filename pakis-1066-text92934.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 76
# Filename pakis-1067-text2174370.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 77
# Filename pakis-1068-text895540.json
#
# Similiar Docs: ['pakis-1628-text3508807.json', 'pakis-717-text565560.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 78
# Filename pakis-1069-text1475757.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 79
# Filename pakis-107-text687481.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 80
# Filename pakis-1070-text3742929.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 81
# Filename pakis-1071-text1510860.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 82
# Filename pakis-1072-text1310676.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 83
# Filename pakis-1073-text312562.json
#
# Similiar Docs: ['pakis-39-text57683.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 84
# Filename pakis-1074-text3319846.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 85
# Filename pakis-1075-text1382056.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 86
# Filename pakis-1076-text1221578.json
#
# Similiar Docs: ['pakis-139-text1792814.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 87
# Filename pakis-1077-text1327178.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 88
# Filename pakis-1078-text3229754.json
#
# Similiar Docs: ['pakis-181-text1752498.json', 'pakis-995-text3383976.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 89
# Filename pakis-1079-text718329.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 90
# Filename pakis-108-text2362958.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 91
# Filename pakis-1080-text1731496.json
#
# Similiar Docs: ['pakis-2039-text1144830.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 92
# Filename pakis-1081-text3656168.json
#
# Similiar Docs: ['pakis-1984-text2489858.json', 'pakis-323-text1381019.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 93
# Filename pakis-1082-text1143841.json
#
# Similiar Docs: ['pakis-1784-text1320752.json', 'pakis-960-text2224235.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 94
# Filename pakis-1083-text1458709.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 95
# Filename pakis-1084-text729423.json
#
# Similiar Docs: ['pakis-831-text1527716.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 96
# Filename pakis-1085-text1553586.json
#
# Similiar Docs: ['pakis-31-text2563194.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 97
# Filename pakis-1086-text1583658.json
#
# Similiar Docs: ['pakis-1495-text1568494.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 98
# Filename pakis-1087-text1998321.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 99
# Filename pakis-1088-text1045499.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 100
# Filename pakis-1089-text1977976.json
#
# Similiar Docs: ['pakis-1677-text687213.json', 'pakis-394-text1330259.json', 'pakis-458-text2372785.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 101
# Filename pakis-109-text3624127.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 102
# Filename pakis-1090-text254226.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 103
# Filename pakis-1091-text959620.json
#
# Similiar Docs: ['pakis-89-text2199299.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 104
# Filename pakis-1092-text858767.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 105
# Filename pakis-1093-text747785.json
#
# Similiar Docs: ['pakis-1141-text3442717.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 106
# Filename pakis-1094-text2580199.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 107
# Filename pakis-1095-text307801.json
#
# Similiar Docs: ['pakis-1154-text1874648.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 108
# Filename pakis-1096-text682132.json
#
# Similiar Docs: ['pakis-1557-text2656815.json', 'pakis-1660-text2778630.json', 'pakis-1781-text419183.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 109
# Filename pakis-1097-text1598949.json
#
# Similiar Docs: ['pakis-2026-text3547637.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 110
# Filename pakis-1098-text3705099.json
#
# Similiar Docs: ['pakis-1626-text3034676.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 111
# Filename pakis-1099-text1915717.json
#
# Similiar Docs: ['pakis-1490-text1166616.json', 'pakis-531-text1099859.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 112
# Filename pakis-11-text164316.json
#
# Similiar Docs: ['pakis-1364-text840602.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 113
# Filename pakis-110-text1204853.json
#
# Similiar Docs: ['pakis-924-text2359135.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 114
# Filename pakis-1100-text346337.json
#
# Similiar Docs: ['pakis-1671-text2624585.json', 'pakis-782-text979827.json', 'pakis-818-text2952321.json', 'pakis-900-text2090253.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 115
# Filename pakis-1101-text1685692.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 116
# Filename pakis-1102-text321997.json
#
# Similiar Docs: ['pakis-1357-text3256223.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 117
# Filename pakis-1103-text2656110.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 118
# Filename pakis-1104-text2531989.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 119
# Filename pakis-1105-text1107735.json
#
# Similiar Docs: ['pakis-116-text2214180.json', 'pakis-807-text2880666.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 120
# Filename pakis-1106-text2923614.json
#
# Similiar Docs: ['pakis-1648-text1302346.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 121
# Filename pakis-1107-text681182.json
#
# Similiar Docs: ['pakis-153-text2307740.json', 'pakis-1696-text106247.json', 'pakis-17-text1736203.json', 'pakis-1932-text3433816.json', 'pakis-647-text694444.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 122
# Filename pakis-1108-text2483204.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 123
# Filename pakis-1109-text2250493.json
#
# Similiar Docs: ['pakis-1115-text111316.json', 'pakis-1866-text3687899.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 124
# Filename pakis-111-text1962884.json
#
# Similiar Docs: ['pakis-478-text3052747.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 125
# Filename pakis-1110-text1965696.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 126
# Filename pakis-1111-text470010.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 127
# Filename pakis-1112-text1442029.json
#
# Similiar Docs: ['pakis-924-text2359135.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 128
# Filename pakis-1113-text3156203.json
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 129
# Filename pakis-1114-text1782655.json
#
# Similiar Docs: ['pakis-1186-text2189489.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 130
# Filename pakis-1115-text111316.json
#
# Similiar Docs: ['pakis-1109-text2250493.json', 'pakis-1866-text3687899.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 131
# Filename pakis-1116-text256037.json
#
# Similiar Docs: ['pakis-1378-text3550385.json', 'pakis-494-text3148661.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 132
# Filename pakis-1117-text1662915.json
#
# Similiar Docs: ['pakis-1220-text596844.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 133
# Filename pakis-1118-text2875888.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 134
# Filename pakis-1119-text3030590.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 135
# Filename pakis-112-text1822396.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 136
# Filename pakis-1120-text1569449.json
#
# Similiar Docs: ['pakis-1326-text3135931.json', 'pakis-1604-text2540561.json', 'pakis-578-text1723655.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 137
# Filename pakis-1121-text3430269.json
#
# Similiar Docs: ['pakis-371-text2743742.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 138
# Filename pakis-1122-text1494033.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 139
# Filename pakis-1123-text2583727.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 140
# Filename pakis-1124-text1896902.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 141
# Filename pakis-1125-text2745271.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 142
# Filename pakis-1126-text3386823.json
#
# Similiar Docs: ['pakis-1359-text2306569.json', 'pakis-1959-text678910.json', 'pakis-912-text2085672.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 143
# Filename pakis-1127-text3461692.json
#
# Similiar Docs: ['pakis-136-text1200054.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 144
# Filename pakis-1128-text2497252.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 145
# Filename pakis-1129-text1819884.json
#
# Similiar Docs: ['pakis-1996-text2006901.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 146
# Filename pakis-113-text3073386.json
#
# Similiar Docs: ['pakis-1204-text620808.json', 'pakis-1411-text975781.json', 'pakis-2086-text634253.json', 'pakis-289-text242141.json', 'pakis-416-text3673595.json', 'pakis-604-text1049189.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 147
# Filename pakis-1130-text2745350.json
#
# Similiar Docs: ['pakis-1042-text1362840.json', 'pakis-1673-text2121009.json', 'pakis-1940-text475435.json', 'pakis-2031-text561532.json', 'pakis-2145-text2676717.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 148
# Filename pakis-1131-text872008.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 149
# Filename pakis-1132-text821420.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 150
# Filename pakis-1133-text2932061.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 151
# Filename pakis-1134-text362820.json
#
# Similiar Docs: ['pakis-151-text2147947.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 152
# Filename pakis-1135-text1822394.json
#
# Similiar Docs: ['pakis-2093-text848685.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 153
# Filename pakis-1136-text1088120.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 154
# Filename pakis-1137-text2453313.json
#
# Similiar Docs: ['pakis-2150-text3599261.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 155
# Filename pakis-1138-text2780251.json
#
# Similiar Docs: ['pakis-78-text1718119.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 156
# Filename pakis-1139-text405758.json
#
# Similiar Docs: ['pakis-336-text725639.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 157
# Filename pakis-114-text1544443.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 158
# Filename pakis-1140-text3405783.json
#
# Similiar Docs: ['pakis-360-text2180971.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 159
# Filename pakis-1141-text3442717.json
#
# Similiar Docs: ['pakis-1093-text747785.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 160
# Filename pakis-1142-text3634095.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 161
# Filename pakis-1143-text1570226.json
#
# Similiar Docs: ['pakis-1627-text181097.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 162
# Filename pakis-1144-text2920798.json
#
# Similiar Docs: ['pakis-1791-text970516.json', 'pakis-1935-text1219486.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 163
# Filename pakis-1145-text1185247.json
#
# Similiar Docs: ['pakis-1601-text2661144.json', 'pakis-18-text1147975.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 164
# Filename pakis-1146-text3229155.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 165
# Filename pakis-1147-text2028713.json
#
# Similiar Docs: ['pakis-1331-text2230154.json', 'pakis-1841-text2838389.json', 'pakis-1895-text1067679.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 166
# Filename pakis-1148-text310783.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 167
# Filename pakis-1149-text2000022.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 168
# Filename pakis-115-text2395052.json
#
# Similiar Docs: ['pakis-340-text3614795.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 169
# Filename pakis-1150-text2970939.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 170
# Filename pakis-1151-text1229844.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 171
# Filename pakis-1152-text3421524.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 172
# Filename pakis-1153-text174071.json
#
# Similiar Docs: ['pakis-174-text2493861.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 173
# Filename pakis-1154-text1874648.json
#
# Similiar Docs: ['pakis-1095-text307801.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 174
# Filename pakis-1155-text1401957.json
#
# Similiar Docs: ['pakis-1542-text754286.json', 'pakis-1737-text776265.json', 'pakis-1760-text2186045.json', 'pakis-246-text1339453.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 175
# Filename pakis-1156-text1826245.json
#
# Similiar Docs: ['pakis-1267-text3233256.json', 'pakis-143-text1649520.json', 'pakis-1609-text3039001.json', 'pakis-824-text1370954.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 176
# Filename pakis-1157-text2817039.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 177
# Filename pakis-1158-text773635.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 178
# Filename pakis-1159-text2294532.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 179
# Filename pakis-116-text2214180.json
#
# Similiar Docs: ['pakis-1105-text1107735.json', 'pakis-807-text2880666.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 180
# Filename pakis-1160-text1850072.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 181
# Filename pakis-1161-text1480305.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 182
# Filename pakis-1162-text401371.json
#
# Similiar Docs: ['pakis-1303-text1353712.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 183
# Filename pakis-1163-text1914246.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 184
# Filename pakis-1164-text1854828.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 185
# Filename pakis-1165-text2022951.json
#
# Similiar Docs: ['pakis-939-text803465.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 186
# Filename pakis-1166-text22786.json
#
# Similiar Docs: ['pakis-1535-text1019461.json', 'pakis-405-text3193087.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 187
# Filename pakis-1167-text2456996.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 188
# Filename pakis-1168-text555986.json
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 189
# Filename pakis-1169-text1865672.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 190
# Filename pakis-117-text2538054.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 191
# Filename pakis-1170-text3401791.json
#
# Similiar Docs: ['pakis-1502-text159846.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 192
# Filename pakis-1171-text2524891.json
#
# Similiar Docs: ['pakis-1037-text1024632.json', 'pakis-1575-text1957188.json', 'pakis-1683-text285930.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 193
# Filename pakis-1172-text3098157.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 194
# Filename pakis-1173-text1194753.json
#
# Similiar Docs: ['pakis-121-text810777.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 195
# Filename pakis-1174-text1312171.json
#
# Similiar Docs: ['pakis-627-text1339284.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 196
# Filename pakis-1175-text2800955.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 197
# Filename pakis-1176-text2694076.json
#
# Similiar Docs: ['pakis-1180-text402619.json', 'pakis-1230-text2929044.json', 'pakis-126-text378071.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 198
# Filename pakis-1177-text3626129.json
#
# Similiar Docs: ['pakis-1247-text1318125.json', 'pakis-133-text1398682.json', 'pakis-1579-text2089750.json', 'pakis-911-text1408778.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 199
# Filename pakis-1178-text1709513.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 200
# Filename pakis-1179-text532260.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 201
# Filename pakis-118-text3506675.json
#
# Similiar Docs: ['pakis-1287-text138503.json', 'pakis-2052-text54952.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 202
# Filename pakis-1180-text402619.json
#
# Similiar Docs: ['pakis-1176-text2694076.json', 'pakis-1230-text2929044.json', 'pakis-126-text378071.json', 'pakis-395-text2186641.json', 'pakis-921-text1930151.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 203
# Filename pakis-1181-text1113854.json
#
# Similiar Docs: ['pakis-669-text1788990.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 204
# Filename pakis-1182-text1468690.json
#
# Similiar Docs: ['pakis-101-text3173079.json', 'pakis-1382-text1959603.json', 'pakis-453-text1632422.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 205
# Filename pakis-1183-text2310613.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 206
# Filename pakis-1184-text1047487.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 207
# Filename pakis-1185-text331072.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 208
# Filename pakis-1186-text2189489.json
#
# Similiar Docs: ['pakis-1114-text1782655.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 209
# Filename pakis-1187-text1124934.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 210
# Filename pakis-1188-text3465025.json
#
# Similiar Docs: ['pakis-1615-text2544985.json', 'pakis-1705-text1172526.json', 'pakis-2085-text511661.json', 'pakis-659-text852908.json', 'pakis-898-text2632460.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 211
# Filename pakis-1189-text2596729.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 212
# Filename pakis-119-text3115885.json
#
# Similiar Docs: ['pakis-666-text2980035.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 213
# Filename pakis-1190-text1572436.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 214
# Filename pakis-1191-text177223.json
#
# Similiar Docs: ['pakis-1417-text3628858.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 215
# Filename pakis-1192-text2510465.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 216
# Filename pakis-1193-text594523.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 217
# Filename pakis-1194-text2979266.json
#
# Similiar Docs: ['pakis-1541-text3032177.json', 'pakis-192-text2984687.json', 'pakis-37-text1721823.json', 'pakis-546-text2951565.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 218
# Filename pakis-1195-text271943.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 219
# Filename pakis-1196-text3039877.json
#
# Similiar Docs: ['pakis-1919-text1639616.json', 'pakis-275-text2823916.json', 'pakis-279-text1988679.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 220
# Filename pakis-1197-text2785134.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 221
# Filename pakis-1198-text3172603.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 222
# Filename pakis-1199-text2782553.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 223
# Filename pakis-12-text493229.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 224
# Filename pakis-120-text1376017.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 225
# Filename pakis-1200-text2975542.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 226
# Filename pakis-1201-text1562871.json
#
# Similiar Docs: ['pakis-1817-text2005064.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 227
# Filename pakis-1202-text3151593.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 228
# Filename pakis-1203-text1489546.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 229
# Filename pakis-1204-text620808.json
#
# Similiar Docs: ['pakis-113-text3073386.json', 'pakis-1411-text975781.json', 'pakis-2086-text634253.json', 'pakis-289-text242141.json', 'pakis-416-text3673595.json', 'pakis-604-text1049189.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 230
# Filename pakis-1205-text62205.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 231
# Filename pakis-1206-text1030753.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 232
# Filename pakis-1207-text687833.json
#
# Similiar Docs: ['pakis-1998-text593004.json', 'pakis-730-text2139316.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 233
# Filename pakis-1208-text399459.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 234
# Filename pakis-1209-text3297998.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 235
# Filename pakis-121-text810777.json
#
# Similiar Docs: ['pakis-1173-text1194753.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 236
# Filename pakis-1210-text3481415.json
#
# Similiar Docs: ['pakis-2118-text103730.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 237
# Filename pakis-1211-text3325952.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 238
# Filename pakis-1212-text2804904.json
#
# Similiar Docs: ['pakis-1904-text3414555.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 239
# Filename pakis-1213-text889989.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 240
# Filename pakis-1214-text312088.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 241
# Filename pakis-1215-text2483349.json
#
# Similiar Docs: ['pakis-2029-text1084072.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 242
# Filename pakis-1216-text365463.json
#
# Similiar Docs: ['pakis-963-text3684543.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 243
# Filename pakis-1217-text2837514.json
#
# Similiar Docs: ['pakis-2113-text630018.json', 'pakis-611-text211845.json', 'pakis-887-text2019248.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 244
# Filename pakis-1218-text1088850.json
#
# Similiar Docs: ['pakis-1744-text1589335.json', 'pakis-495-text1497130.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 245
# Filename pakis-1219-text1745144.json
#
# Similiar Docs: ['pakis-1793-text2823475.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 246
# Filename pakis-122-text2462650.json
#
# Similiar Docs: ['pakis-1749-text3602965.json', 'pakis-23-text2822076.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 247
# Filename pakis-1220-text596844.json
#
# Similiar Docs: ['pakis-1117-text1662915.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 248
# Filename pakis-1221-text2040456.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 249
# Filename pakis-1222-text1540061.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 250
# Filename pakis-1223-text2273232.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 251
# Filename pakis-1224-text735930.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 252
# Filename pakis-1225-text2078672.json
#
# Similiar Docs: ['pakis-1256-text2168942.json', 'pakis-2109-text1753748.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 253
# Filename pakis-1226-text1983507.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 254
# Filename pakis-1227-text1915624.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 255
# Filename pakis-1228-text2662538.json
#
# Similiar Docs: ['pakis-1356-text2306129.json', 'pakis-1734-text1669212.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 256
# Filename pakis-1229-text2029727.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 257
# Filename pakis-123-text3138066.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 258
# Filename pakis-1230-text2929044.json
#
# Similiar Docs: ['pakis-1176-text2694076.json', 'pakis-1180-text402619.json', 'pakis-126-text378071.json', 'pakis-921-text1930151.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 259
# Filename pakis-1231-text17667.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 260
# Filename pakis-1232-text3553800.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 261
# Filename pakis-1233-text3745583.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 262
# Filename pakis-1234-text1617231.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 263
# Filename pakis-1235-text958599.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 264
# Filename pakis-1236-text3397638.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 265
# Filename pakis-1237-text1794934.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 266
# Filename pakis-1238-text3125619.json
#
# Similiar Docs: []
# -------------------------------------
#
# ...
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2061
# Filename pakis-918-text386616.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2062
# Filename pakis-919-text3535173.json
#
# Similiar Docs: ['pakis-1334-text1746080.json', 'pakis-2005-text1471753.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2063
# Filename pakis-92-text233262.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2064
# Filename pakis-920-text315575.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2065
# Filename pakis-921-text1930151.json
#
# Similiar Docs: ['pakis-1180-text402619.json', 'pakis-1230-text2929044.json', 'pakis-395-text2186641.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2066
# Filename pakis-922-text2537851.json
#
# Similiar Docs: ['pakis-1507-text2971864.json', 'pakis-1613-text174568.json', 'pakis-987-text1816816.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2067
# Filename pakis-923-text667345.json
#
# Similiar Docs: ['pakis-816-text2457118.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2068
# Filename pakis-924-text2359135.json
#
# Similiar Docs: ['pakis-110-text1204853.json', 'pakis-1112-text1442029.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2069
# Filename pakis-925-text1634552.json
#
# Similiar Docs: ['pakis-760-text1742722.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2070
# Filename pakis-926-text1616572.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2071
# Filename pakis-927-text1626599.json
#
# Similiar Docs: ['pakis-1545-text1444974.json', 'pakis-1684-text3428546.json', 'pakis-634-text807643.json', 'pakis-737-text70326.json', 'pakis-944-text2196095.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2072
# Filename pakis-928-text1252130.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2073
# Filename pakis-929-text347713.json
#
# Similiar Docs: ['pakis-342-text1422458.json', 'pakis-739-text1268800.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2074
# Filename pakis-93-text2492598.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2075
# Filename pakis-930-text1031288.json
#
# Similiar Docs: ['pakis-1009-text806101.json', 'pakis-539-text2204775.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2076
# Filename pakis-931-text346179.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2077
# Filename pakis-932-text566880.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2078
# Filename pakis-933-text3533411.json
#
# Similiar Docs: ['pakis-880-text918380.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2079
# Filename pakis-934-text3740696.json
#
# Similiar Docs: ['pakis-1241-text3160517.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2080
# Filename pakis-935-text836309.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2081
# Filename pakis-936-text3698559.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2082
# Filename pakis-937-text3067444.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2083
# Filename pakis-938-text1724271.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2084
# Filename pakis-939-text803465.json
#
# Similiar Docs: ['pakis-1165-text2022951.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2085
# Filename pakis-94-text1239238.json
#
# Similiar Docs: ['pakis-1833-text1897793.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2086
# Filename pakis-940-text3393684.json
#
# Similiar Docs: ['pakis-908-text1803294.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2087
# Filename pakis-941-text3635437.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2088
# Filename pakis-942-text3543671.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2089
# Filename pakis-943-text2319580.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2090
# Filename pakis-944-text2196095.json
#
# Similiar Docs: ['pakis-1545-text1444974.json', 'pakis-1684-text3428546.json', 'pakis-634-text807643.json', 'pakis-737-text70326.json', 'pakis-927-text1626599.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2091
# Filename pakis-945-text572172.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2092
# Filename pakis-946-text1793662.json
#
# Similiar Docs: ['pakis-1569-text144153.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2093
# Filename pakis-947-text494920.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2094
# Filename pakis-948-text301437.json
#
# Similiar Docs: ['pakis-1774-text720448.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2095
# Filename pakis-949-text2266503.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2096
# Filename pakis-95-text1386303.json
#
# Similiar Docs: ['pakis-2034-text1679312.json', 'pakis-598-text1394959.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2097
# Filename pakis-950-text1243025.json
#
# Similiar Docs: ['pakis-1033-text2233829.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2098
# Filename pakis-951-text3558761.json
#
# Similiar Docs: ['pakis-1281-text1564919.json', 'pakis-2130-text370457.json', 'pakis-265-text2158359.json', 'pakis-349-text2387047.json', 'pakis-436-text3294428.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2099
# Filename pakis-952-text1801604.json
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2100
# Filename pakis-953-text214968.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2101
# Filename pakis-954-text1696883.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2102
# Filename pakis-955-text3579961.json
#
# Similiar Docs: ['pakis-1054-text1600800.json', 'pakis-1747-text484599.json', 'pakis-2099-text2425204.json', 'pakis-8-text301234.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2103
# Filename pakis-956-text3281148.json
#
# Similiar Docs: ['pakis-200-text1729486.json', 'pakis-252-text3233144.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2104
# Filename pakis-957-text1807403.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2105
# Filename pakis-958-text3487904.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2106
# Filename pakis-959-text3643953.json
#
# Similiar Docs: ['pakis-1518-text777214.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2107
# Filename pakis-96-text997134.json
#
# Similiar Docs: ['pakis-1388-text3477132.json', 'pakis-1529-text3699461.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2108
# Filename pakis-960-text2224235.json
#
# Similiar Docs: ['pakis-1082-text1143841.json', 'pakis-1651-text3294425.json', 'pakis-1784-text1320752.json', 'pakis-364-text2660353.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2109
# Filename pakis-961-text1932037.json
#
# Similiar Docs: ['pakis-20-text2835524.json', 'pakis-445-text2508681.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2110
# Filename pakis-962-text266078.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2111
# Filename pakis-963-text3684543.json
#
# Similiar Docs: ['pakis-1216-text365463.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2112
# Filename pakis-964-text2742486.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2113
# Filename pakis-965-text3083201.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2114
# Filename pakis-966-text739682.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2115
# Filename pakis-967-text1217869.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2116
# Filename pakis-968-text730368.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2117
# Filename pakis-969-text2137518.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2118
# Filename pakis-97-text765490.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2119
# Filename pakis-970-text3242711.json
#
# Similiar Docs: ['pakis-1831-text1740814.json', 'pakis-423-text3004846.json', 'pakis-770-text2329492.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2120
# Filename pakis-971-text815575.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2121
# Filename pakis-972-text1851353.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2122
# Filename pakis-973-text2020954.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2123
# Filename pakis-974-text1179660.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2124
# Filename pakis-975-text270020.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2125
# Filename pakis-976-text1555224.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2126
# Filename pakis-977-text3635658.json
#
# Similiar Docs: ['pakis-100-text3397292.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2127
# Filename pakis-978-text348118.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2128
# Filename pakis-979-text851799.json
#
# Similiar Docs: ['pakis-367-text3287249.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2129
# Filename pakis-98-text2585119.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2130
# Filename pakis-980-text1274591.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2131
# Filename pakis-981-text1082491.json
#
# Similiar Docs: ['pakis-1857-text3314292.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2132
# Filename pakis-982-text3191687.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2133
# Filename pakis-983-text2051844.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2134
# Filename pakis-984-text2826951.json
#
# Similiar Docs: ['pakis-533-text802035.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2135
# Filename pakis-985-text553068.json
#
# Similiar Docs: ['pakis-1926-text3243255.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2136
# Filename pakis-986-text2477407.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2137
# Filename pakis-987-text1816816.json
#
# Similiar Docs: ['pakis-1507-text2971864.json', 'pakis-1613-text174568.json', 'pakis-922-text2537851.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2138
# Filename pakis-988-text1312531.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2139
# Filename pakis-989-text2234168.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2140
# Filename pakis-99-text531797.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2141
# Filename pakis-990-text1906179.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2142
# Filename pakis-991-text2602816.json
#
# Similiar Docs: ['pakis-1574-text2443644.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2143
# Filename pakis-992-text130066.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2144
# Filename pakis-993-text2766786.json
#
# Similiar Docs: ['pakis-879-text1037161.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2145
# Filename pakis-994-text3407843.json
#
# Similiar Docs: []
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2146
# Filename pakis-995-text3383976.json
#
# Similiar Docs: ['pakis-1078-text3229754.json', 'pakis-181-text1752498.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2147
# Filename pakis-996-text2659057.json
#
# Similiar Docs: ['pakis-1050-text939146.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2148
# Filename pakis-997-text3321766.json
#
# Similiar Docs: ['pakis-889-text1796861.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2149
# Filename pakis-998-text1298047.json
#
# Similiar Docs: ['pakis-1059-text2176935.json', 'pakis-510-text1531958.json']
# -------------------------------------
#
# -------------------------------------
# Analyzing doc # 2150
# Filename pakis-999-text1748878.json
#
# Similiar Docs: []
# -------------------------------------
